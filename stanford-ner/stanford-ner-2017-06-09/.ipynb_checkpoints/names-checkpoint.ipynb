# %%
import pandas as pd
import nltk
from nltk.tag.stanford import StanfordNERTagger
import ctypes, sys
import subprocess

# %%
st = StanfordNERTagger('english.all.3class.distsim.crf.ser.gz',
                       'stanford-ner.jar')

# %%
df = pd.read_csv('C:/Users/willi/OneDrive/Documents/GitHub/Revolving_Door_Network_Project/df.csv')

# %%
text = text = u"""
Some economists have responded positively to Bitcoin, including
Francois R. Velde, senior economist of the Federal Reserve in Chicago
who described it as "an elegant solution to the problem of creating a
digital currency." In November 2013 Richard Branson announced that
Virgin Galactic would accept Bitcoin as payment, saying that he had invested
in Bitcoin and found it "fascinating how a whole new global currency
has been created", encouraging others to also invest in Bitcoin.
Other economists commenting on Bitcoin have been critical.
Economist Paul Krugman has suggested that the structure of the currency
incentivizes hoarding and that its value derives from the expectation that
others will accept it as payment. Economist Larry Summers has expressed
a "wait and see" attitude when it comes to Bitcoin. Nick Colas, a market
strategist for ConvergEx Group, has remarked on the effect of increasing
use of Bitcoin and its restricted supply, noting, "When incremental
adoption meets relatively fixed supply, it should be no surprise that
prices go up. And that’s exactly what is happening to BTC prices.
"""

# %%
def is_admin():
    try:
        return ctypes.windll.shell32.IsUserAnAdmin()
    except:
        return False

if is_admin():
    for row in df['position']:
        for word in nltk.sent_tokenize(row):
            tokens = nltk.tokenize.word_tokenize(word)
            tags = st.tag(tokens)
            for tag in tags:
                print(tag)
    else:
        # Re-run the program with admin rights
        ctypes.windll.shell32.ShellExecuteW(None, "runas", sys.executable, __file__, None, 1)

# %%
is_admin()
# Out:
# 0

# %%
df
# Out:
#                   lobbyist_name  \
# 0                 Jessica Tocco
# 1              Patrick Anderson
# 2             Matthew Weinstein
# 3                   Todd Harmer
# 4                    Dave Myers
# 5             Jonathan McCollum
# 6               Chelsey Hickman
# 7                    Jake Perry
# 8                  Amy Lombardo
# 9              Gregg Rothschild
# 10                 Susan Brophy
# 11                   Gina Foote
# 12                  Rob Seidman
# 13                  Clint Lohse
# 14                  Cody Hoefer
# 15               Leslie Belcher
# 16                   John Lundy
# 17                 Susan Butler
# 18                     Ty Mabry
# 19               Marla Grossman
# 20           Greg Schildwachter
# 21                Daniel McFaul
# 22                   Sean Joyce
# 23                  Edward Hild
# 24                      Will Le
# 25               Keith Studdard
# 26              Dana DeBeaumont
# 27               Patrick Martin
# 28               Robert Freeman
# 29             Alexandra Campau
# ..                          ...
# 844             Lisa Kountoupes
# 845                  Randi Reid
# 846                David Peluso
# 847                 Lori Denham
# 848          Julie Hershey Carr
# 849            Martin Cancienne
# 850                Tracy Spicer
# 851                Brendan Dunn
# 852               Virgil Miller
# 853                 Caryn Dyson
# 854               Virgil Miller
# 855               Sam Olswanger
# 856                 James Flood
# 857                 Byron Brown
# 858        Saira Sultan Chirico
# 859                 David Jones
# 860          R. James Nicholson
# 861                 Aleta Greer
# 862                 Hope Hurley
# 863                  Scott Klug
# 864          Theodore Bornstein
# 865              Jennifer Walsh
# 866                 Bart Stupak
# 867            Kendrick B. Meek
# 868             Jeffery Mortier
# 869             Thomas Reynolds
# 870               Sally Vastola
# 871           Federico de Jesus
# 872              Oswaldo Palomo
# 873  Douglas C. "Mike" McIntyre
#
#                                               position
# 0    Confidential Assistant to Carlos Gutierrez, Se...
# 1    Legislative Advisor to Representative Henry Bo...
# 2    Legislative Director to Rep Byrne, Sr LA to Re...
# 3                                  LA to Sen Chambliss
# 4          LA to Sen Domenici, Exec Asst to Sen DAmato
# 5                  Legislative Assistant to US Senator
# 6           CoS, Rep. Kay Granger; LA Sen. Larry Craig
# 7                    Legislative Aide, Sen. Harry Reid
# 8    Staff/Scheduler Congressman Michael K. Simpson...
# 9    Legislative Assistant, Senator John Kerry; Cou...
# 10   Chief of Staff, Representative Byron Dorgan; C...
# 11   Chief of Staff, Rep. Ted Poe; Legislative Coun...
# 12   Legislative Assistant, Sen. Kelly Ayotte; Poli...
# 13   Legislative Assistant to Sen. Mike Enzi (R-Wyo...
# 14   National Defense Military Policy Advisor / Sen...
# 15   Chief of Staff; Reps. Tom Cole (OK-4) and Wes ...
# 16   COS to Sen. Trent Lott; LA to Rep. Larry Combe...
# 17   COS to Rep. Chip Pickering; LA to Sen. Trent Lott
# 18    Deputy Legislative Director to Sen. Thad Cochran
# 19        Minority Counsel, Senate Judiciary Committee
# 20       US Senate; Executive Office of the President.
# 21   ​​Leg Dir to U.S. Rep. Joe Scarborough. Chief ...
# 22   Chief of Staff for Congressman Patrick McHenry...
# 23                 Chief of Staff, Sen. Lisa Murkowski
# 24   Office Manager, Committee on House Administrat...
# 25         Legislative Director, Rep. Marsha Blackburn
# 26                                             Partner
# 27   Legislative Correspondent - Office of Senator ...
# 28   Deputy Chief of Staff, Senate Commerce; Admini...
# 29   Health Policy Advisor and Counsel, House Budge...
# ..                                                 ...
# 844  Deputy Asst. to the President&House Liaison, S...
# 845  Legislative Director, Legislative Assistant an...
# 846  Chief of Staff - Representative Cathy McMorris...
# 847  Chief of Staff, Legislative Director, Legislat...
# 848  Senior Policy Advisor, Legislative Director, L...
# 849         Frm. COS, COO, and Dist. Dir. Cong. Tauzin
# 850  Deputy Chief of Staff, Political Director, Leg...
# 851  Staff Mbr and Leg Asst to Sen Hatch Judiciary ...
# 852  Policy Fellow, Rep. Edolphus Towns, Aug06 - Fe...
# 853  Prof staff mbr to Sen Breaux, 2003-04; Intrn t...
# 854  Policy Fellow, Rep. Edolphus Towns, Aug06 - Fe...
# 855  Leg staff, Rep Webster, Jan 11-Jun 11; intrn, ...
# 856  Counsel - Senate Judiciary Committee (Sen. Sch...
# 857  Deputy Chief of Staff - EPA; Senior Counsel - ...
# 858  US Senate HELP Committee, Employment Subcommit...
# 859  Counsel/Chief Antitrust Counsel, Senate Judici...
# 860  Secretary Dept of Veterans Affairs; Ambassador...
# 861  Intern, Senate Banking Committee; Intern, Rep ...
# 862  Press Assistant, Sen. James Webb; Intern, Rep....
# 863                       Member of Congress 1991-1999
# 864             COS Rep. Aspin; COS Sen. Kohl; OSD-DOD
# 865  Administrative Assistant, Deputy COS, COS: Rep...
# 866                     U.S. Representative, 1993-2011
# 867             U.S. Representative (FL-17), 2002-2010
# 868  Prof Staff on E&C Cmte LA Rep Whitfield and In...
# 869                              Member, U.S. Congress
# 870               Chief of Staff, Rep. Thomas Reynolds
# 871                      Principal, FDJ Solutions, LLC
# 872      L.A., Rep. Walsh, Staff Assistant, Rep. Walsh
# 873                                 former Congressman
#
# [874 rows x 2 columns]

# %%
tag_list = []

# %%
def is_admin():
    try:
        return ctypes.windll.shell32.IsUserAnAdmin()
    except:
        return False

if is_admin():
    for row in df['position']:
        for word in nltk.sent_tokenize(row):
            tokens = nltk.tokenize.word_tokenize(word)
            tags = st.tag(tokens)
            for tag in tags:
                if tag[1] in ["PERSON"]:
                    tag_list.append(tag)
    else:
        # Re-run the program with admin rights
        ctypes.windll.shell32.ShellExecuteW(None, "runas", sys.executable, __file__, None, 1)

# %%
tag_list
# Out:
# []

# %%
for row in df['position']:
    for word in nltk.sent_tokenize(row):
        tokens = nltk.tokenize.word_tokenize(word)
        tags = st.tag(tokens)
        for tag in tags:
            if tag[1] in ["PERSON"]:
                print(tag)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-37-c41aa3b4c4ad> in <module>()
#       3     for word in nltk.sent_tokenize(row):
#       4         tokens = nltk.tokenize.word_tokenize(word)
# ----> 5         tags = st.tag(tokens)
#       6         for tag in tags:
#       7             if tag[1] in ["PERSON"]:
#
# ~\Anaconda3\lib\site-packages\nltk\tag\stanford.py in tag(self, tokens)
#      79     def tag(self, tokens):
#      80         # This function should return list of tuple rather than list of list
# ---> 81         return sum(self.tag_sents([tokens]), [])
#      82
#      83     def tag_sents(self, sentences):
#
# ~\Anaconda3\lib\site-packages\nltk\tag\stanford.py in tag_sents(self, sentences)
#     102         # Run the tagger and get the output
#     103         stanpos_output, _stderr = java(cmd, classpath=self._stanford_jar,
# --> 104                                        stdout=PIPE, stderr=PIPE)
#     105         stanpos_output = stanpos_output.decode(encoding)
#     106
#
# ~\Anaconda3\lib\site-packages\nltk\__init__.py in java(cmd, classpath, stdin, stdout, stderr, blocking)
#     127
#     128     # Call java via a subprocess
# --> 129     p = subprocess.Popen(cmd, stdin=stdin, stdout=stdout, stderr=stderr)
#     130     if not blocking: return p
#     131     (stdout, stderr) = p.communicate()
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     754                                 c2pread, c2pwrite,
#     755                                 errread, errwrite,
# --> 756                                 restore_signals, start_new_session)
#     757         except:
#     758             # Cleanup if the child failed starting.
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1153                                          env,
#    1154                                          os.fspath(cwd) if cwd is not None else None,
# -> 1155                                          startupinfo)
#    1156             finally:
#    1157                 # Child is launched. Close the parent's copy of those pipe
#
# OSError: [WinError 740] The requested operation requires elevation

# %%
text = u"""
Some economists have responded positively to Bitcoin, including
Francois R. Velde, senior economist of the Federal Reserve in Chicago
who described it as "an elegant solution to the problem of creating a
digital currency." In November 2013 Richard Branson announced that
Virgin Galactic would accept Bitcoin as payment, saying that he had invested
in Bitcoin and found it "fascinating how a whole new global currency
has been created", encouraging others to also invest in Bitcoin.
Other economists commenting on Bitcoin have been critical.
Economist Paul Krugman has suggested that the structure of the currency
incentivizes hoarding and that its value derives from the expectation that
others will accept it as payment. Economist Larry Summers has expressed
a "wait and see" attitude when it comes to Bitcoin. Nick Colas, a market
strategist for ConvergEx Group, has remarked on the effect of increasing
use of Bitcoin and its restricted supply, noting, "When incremental
adoption meets relatively fixed supply, it should be no surprise that
prices go up. And that’s exactly what is happening to BTC prices.
"""


for sent in nltk.sent_tokenize(text):
    tokens = nltk.tokenize.word_tokenize(sent)
    tags = st.tag(tokens)
    for tag in tags:
        if tag[1] in ["PERSON", "LOCATION", "ORGANIZATION"]:
            print(tag)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-60-153c06d746d6> in <module>()
#      21 for sent in nltk.sent_tokenize(text):
#      22     tokens = nltk.tokenize.word_tokenize(sent)
# ---> 23     tags = st.tag(tokens)
#      24     for tag in tags:
#      25         if tag[1] in ["PERSON", "LOCATION", "ORGANIZATION"]:
#
# ~\Anaconda3\lib\site-packages\nltk\tag\stanford.py in tag(self, tokens)
#      79     def tag(self, tokens):
#      80         # This function should return list of tuple rather than list of list
# ---> 81         return sum(self.tag_sents([tokens]), [])
#      82
#      83     def tag_sents(self, sentences):
#
# ~\Anaconda3\lib\site-packages\nltk\tag\stanford.py in tag_sents(self, sentences)
#     102         # Run the tagger and get the output
#     103         stanpos_output, _stderr = java(cmd, classpath=self._stanford_jar,
# --> 104                                        stdout=PIPE, stderr=PIPE)
#     105         stanpos_output = stanpos_output.decode(encoding)
#     106
#
# ~\Anaconda3\lib\site-packages\nltk\__init__.py in java(cmd, classpath, stdin, stdout, stderr, blocking)
#     127
#     128     # Call java via a subprocess
# --> 129     p = subprocess.Popen(cmd, stdin=stdin, stdout=stdout, stderr=stderr)
#     130     if not blocking: return p
#     131     (stdout, stderr) = p.communicate()
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     754                                 c2pread, c2pwrite,
#     755                                 errread, errwrite,
# --> 756                                 restore_signals, start_new_session)
#     757         except:
#     758             # Cleanup if the child failed starting.
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1153                                          env,
#    1154                                          os.fspath(cwd) if cwd is not None else None,
# -> 1155                                          startupinfo)
#    1156             finally:
#    1157                 # Child is launched. Close the parent's copy of those pipe
#
# OSError: [WinError 740] The requested operation requires elevation
